# %% [markdown]
# **Test if important libs works**

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Testbild erstellen
data = np.random.rand(100, 100, 3) * 255
image = Image.fromarray(data.astype('uint8'))

# Bild anzeigen
plt.imshow(image)
plt.show()

# %%
# Import necessary libraries
import torch
import tensorflow as tf

# PyTorch version and CUDA/cuDNN details
print("PyTorch Version:", torch.__version__)
if torch.cuda.is_available():
    print("CUDA Available: Yes")
    print("CUDA Version:", torch.version.cuda)
    print("cuDNN Version:", torch.backends.cudnn.version())
else:
    print("CUDA Available: No")

# TensorFlow version and CUDA/cuDNN details
print("\nTensorFlow Version:", tf.__version__)
if tf.test.is_built_with_cuda():
    print("Built with CUDA: Yes")
    gpu_devices = tf.config.list_physical_devices('GPU')
    print("GPUs Available:", len(gpu_devices))
else:
    print("Tensorflow found no GPU")
# Out:
# d:\Programme\Anaconda\envs\wavetable_new\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# PyTorch Version: 1.8.1+cu101
# CUDA Available: Yes
# CUDA Version: 10.1
# cuDNN Version: 7604
#
# TensorFlow Version: 2.3.0
# Built with CUDA: Yes
# GPUs Available: 1
# CUDA Version: Cannot directly get from TensorFlow (use system info)

# %%
# !python preprocess.py # call iny once wo preprocess audio files

# %%
from jupyter_train import run_training

run_training(epochs=1)
